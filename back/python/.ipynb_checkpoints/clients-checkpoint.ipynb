# %%
# clients.ipynb
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# URL del endpoint de la API
url = 'http://localhost:26968/clientes'

# Hacer la solicitud GET
response = requests.get(url)

# Verificar si la respuesta fue exitosa
if response.status_code == 200:
    data = response.json()  # Convertir la respuesta a formato JSON
    
    df = pd.DataFrame(data)

    print(df)

    # Graficar los resultados
    plt.figure(figsize=(12, 6))
    plt.bar(df['nombre_cliente'], df['total_gastado'], color='skyblue')
    plt.xlabel('Clientes')
    plt.ylabel('Total Gastado')
    plt.title('Total Gastado por Cliente')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print(f'Error en la solicitud: {response.status_code}')
# Out:
# ho! 0    0
# 1    0
# Name: total_gastado, dtype: int64
